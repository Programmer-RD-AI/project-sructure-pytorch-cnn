# %%
from tqdm import tqdm
import torch
import wandb
import torch.nn as nn
from torchvision import models
from data_loading.data_loader import *
from data_loading.transforming import *

device = torch.device("cuda")
loaded_data = load_all_data()
EPOCHS = 100
model = models.resnet18(pretrained=True).to(device)
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, 37)
model.to(device)
criterion = nn.CrossEntropyLoss().to(device)
optimizer = torch.optim.SGD(model.parameters(), lr=0.1)
PROJECT_NAME = "Face-Mask-Detection-PT-V2"
# Out:
# 1006
# /home/indika/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
wandb.init(project=PROJECT_NAME, name="testing")
for _ in tqdm(range(EPOCHS), leave=False):
    for data, label in tqdm(loaded_data, leave=False):
        data = data.to(device)
        label = label.to(device)
        preds = model(data.float())
        preds = preds.to(device)
        loss = criterion(preds, label)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        wandb.log({"loss": loss.item()})
# Out:
# wandb: Currently logged in as: ranuga-d (use `wandb login --relogin` to force relogin)
#                 Tracking run with wandb version 0.10.30<br/>
#                 Syncing run <strong style="color:#cdcd00">testing</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/ranuga-d/Face-Mask-Detection-PT-V2" target="_blank">https://wandb.ai/ranuga-d/Face-Mask-Detection-PT-V2</a><br/>
#                 Run page: <a href="https://wandb.ai/ranuga-d/Face-Mask-Detection-PT-V2/runs/8iklanca" target="_blank">https://wandb.ai/ranuga-d/Face-Mask-Detection-PT-V2/runs/8iklanca</a><br/>
#                 Run data is saved locally in <code>/home/indika/Programming/Projects/Python/Artifical-Intelligence/PyTorch/CNN/Mask-Detection-PT-V2/wandb/run-20210521_202716-8iklanca</code><br/><br/>
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   3%|▎         | 1/32 [00:00<00:24,  1.26it/s]
#  12%|█▎        | 4/32 [00:00<00:05,  5.42it/s]
#  22%|██▏       | 7/32 [00:01<00:02,  9.27it/s]
#  28%|██▊       | 9/32 [00:01<00:02, 10.76it/s]
#  34%|███▍      | 11/32 [00:01<00:01, 12.63it/s]
#  41%|████      | 13/32 [00:01<00:01, 14.24it/s]
#  50%|█████     | 16/32 [00:01<00:00, 16.89it/s]
#  59%|█████▉    | 19/32 [00:01<00:00, 18.56it/s]
#  69%|██████▉   | 22/32 [00:01<00:00, 19.47it/s]
#  78%|███████▊  | 25/32 [00:01<00:00, 20.46it/s]
#  88%|████████▊ | 28/32 [00:02<00:00, 21.29it/s]
#  97%|█████████▋| 31/32 [00:02<00:00, 20.22it/s]
#   1%|          | 1/100 [00:02<03:42,  2.25s/it]
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#  38%|███▊      | 38/100 [00:02<00:02, 22.49it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#  90%|█████████ | 90/100 [00:02<00:00, 61.50it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#   0%|          | 0/32 [00:00<?, ?it/s]
